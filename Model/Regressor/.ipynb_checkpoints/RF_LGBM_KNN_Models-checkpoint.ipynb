# %% [markdown]
# ### **Data Cleaning**

# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load CSV File
listings = pd.read_csv('listings-masters-modeling.csv', error_bad_lines = False)
listings
# Out:
#              id  ... instant_bookable
# 0          2595  ...                0
# 1          3831  ...                0
# 2          5121  ...                0
# 3          5178  ...                0
# 4        279857  ...                1
# ...         ...  ...              ...
# 36918  46937371  ...                0
# 36919  46937954  ...                0
# 36920  46938514  ...                0
# 36921  46938537  ...                0
# 36922  46941857  ...                0
#
# [36923 rows x 49 columns]

# %%
# Determine which amenities have the highest count to vectorize data 

pd.Series(np.concatenate(listings['amenities'].map(lambda amns: amns.split(","))))\
    .value_counts().head(10)\
    .plot(kind='bar')
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)
plt.show();

# %%
# Determine # of listings for each neighbourhood
count_per_neighbourhood = listings['neighbourhoodid'].value_counts()
ax = count_per_neighbourhood.plot(kind='bar', figsize = (10,6), color = '#E35A5C', alpha = 0.85)
ax.set_title("Neighbourhoods by Number of Listings")
ax.set_xlabel("Neighbourhoods ID")
ax.set_ylabel("# of Listings")
plt.show()

# %%
# Filter out neighbourhoods that have <100 listings
relevant_neighbourhoods = count_per_neighbourhood[count_per_neighbourhood > 100].index
listings_cleaned = listings[listings['neighbourhoodid'].isin(relevant_neighbourhoods)]

# %%
# Plot neighbouhood ID by listings (more than 100)
count_per_neighbourhood = listings_cleaned ['neighbourhoodid'].value_counts()
ax = count_per_neighbourhood.plot(kind='bar', figsize = (10,6), color = '#E35A5C', alpha = 0.85)
ax.set_title("Neighbourhood ID by Number of Listings")
ax.set_xlabel("NeighbouhoodID")
ax.set_ylabel("# of Listings")

plt.show()

print('Number of entries removed: ', listings.shape[0] - listings_cleaned.shape[0])
# Out:
# Number of entries removed:  4042

# %%
# Plot the listing price distribution 

histogram = listings.loc[(listings.price <= 3000) & (listings.price > 0)].price.hist(bins=200, figsize=(10,6), color = '#E35A5C', grid=False)
plt.ylabel('Count')
plt.xlabel('Listing price in $')
plt.title('Histogram of listing prices')
# Out:
# Text(0.5, 1.0, 'Histogram of listing prices')

# %%
# Plot the listing price distribution < 600 so model data will be less skewed

histogram = listings.loc[(listings.price <= 600) & (listings.price > 0)].price.hist(bins=200, figsize=(10,6), color = '#E35A5C', grid = False)
plt.ylabel('Count')
plt.xlabel('Listing price in $')
plt.title('Histogram of listing prices')
# Out:
# Text(0.5, 1.0, 'Histogram of listing prices')

# %%
# Filter out the listing prices less than $600

listings_cleaned = listings_cleaned.loc[(listings_cleaned.price <= 600)]

# %%
# Display all the columns of the listings cleaned DF
listings_cleaned.columns
# Out:
# Index(['id', 'listing_url', 'name', 'description', 'picture_url', 'hostid',
#        'host_since', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'superhost', 'host_listings_count',
#        'host_identity_verified', 'neighbourhoodid', 'borough_id', 'latitude',
#        'longitude', 'room_typeid', 'accommodates', 'bathrooms_text',
#        'bathrooms', 'bedrooms', 'beds', 'amenities', 'amenities_count',
#        'Kitchen', 'Heating', 'Essentials', 'Air Conditioning', 'TV', 'Washer',
#        'Dryer', 'Iron', 'Parking', 'price', 'minimum_nights', 'maximum_nights',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'number_of_reviews', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'instant_bookable'],
#       dtype='object')

# %% [markdown]
# ### **Impute Missing Values**

# %%
# Impute data for missing value with teh average mean of that specific column
listings_cleaned=listings_cleaned.fillna(listings_cleaned.mean())

# %% [markdown]
# ### **Price Correlation Matrix**

# %%
# copy the listings cleaned DF
temp = listings_cleaned.copy()

# %%
# Choose columns that may have the highest correlation with price
temp_scores = temp[['accommodates', 'amenities_count', 'bathrooms', 'bedrooms', 'beds', 'Heating', 'Air Conditioning', 'Washer', 'Dryer', 'room_typeid', 'neighbourhoodid', 'price']]

# %%
# Create values for the corelation values
corr_matrix = temp_scores.corr()

corr_matrix
# Out:
#                   accommodates  amenities_count  ...  neighbourhoodid     price
# accommodates          1.000000         0.237597  ...        -0.040642  0.513151
# amenities_count       0.237597         1.000000  ...        -0.040331  0.154083
# bathrooms             0.264957         0.110841  ...        -0.077606  0.202020
# bedrooms              0.685774         0.151278  ...        -0.054049  0.438827
# beds                  0.717088         0.216666  ...        -0.029900  0.377806
# Heating               0.071406         0.229687  ...         0.008092  0.036203
# Air Conditioning      0.140514         0.277956  ...        -0.004064  0.152038
# Washer                0.141730         0.348811  ...        -0.038504  0.200806
# Dryer                 0.148593         0.455108  ...        -0.005289  0.140902
# room_typeid          -0.435094        -0.130298  ...         0.003111 -0.428196
# neighbourhoodid      -0.040642        -0.040331  ...         1.000000  0.062638
# price                 0.513151         0.154083  ...         0.062638  1.000000
#
# [12 rows x 12 columns]

# %%
# Plot correltion heatmap
plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix, annot= True)

# %% [markdown]
# ### **Feature Selection**

# %%
listings_cleaned = listings_cleaned[['neighbourhoodid','superhost', 'host_identity_verified', 'host_listings_count', 'room_typeid', 'accommodates', 'amenities_count','bathrooms', 'bedrooms', 'beds', 'Heating', 'Essentials', 'Kitchen', 'Air Conditioning', 'Washer', 'Dryer', 'Parking','minimum_nights','number_of_reviews', 'review_scores_rating','price']]
listings_cleaned
# Out:
#        neighbourhoodid  superhost  ...  review_scores_rating  price
# 0                  115        0.0  ...             94.000000    175
# 1                   63        0.0  ...             89.000000     74
# 2                   52        0.0  ...             90.000000     60
# 3                  115        0.0  ...             84.000000     65
# 5                  127        0.0  ...             98.000000     75
# ...                ...        ...  ...                   ...    ...
# 36918              111        0.0  ...             93.811609    199
# 36919              127        0.0  ...             93.811609    205
# 36920              102        1.0  ...             93.811609     35
# 36921              111        0.0  ...             93.811609    295
# 36922               60        1.0  ...             93.811609    500
#
# [32241 rows x 21 columns]

# %%
y = listings_cleaned['price']
x = listings_cleaned.drop('price', axis =1)

# %% [markdown]
# ### **Split Train-Test Data**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.35, random_state=42)

# %% [markdown]
# ### **Preprocessing Data & Scaling to Fit the model**

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler,StandardScaler
from tensorflow.keras.utils import to_categorical

# Scale your data
from sklearn.preprocessing import StandardScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### **Random Forest Regressor**

# %%
# Set the parameters for the random forest regressor
rf = RandomForestRegressor(n_estimators=500, 
                               criterion='mse', 
                               random_state=42, 
                               max_features='auto',
                               )

# %%
# Run the model
rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=500, n_jobs=None, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
## Predict the scores with the test Data & calculate r2 & mean squared error results
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

y_train_pred = rf.predict(X_train_scaled)
y_test_pred = rf.predict(X_test_scaled)
rmse_rf= (mean_squared_error(y_test,y_test_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_test_pred)))
# Out:
# RMSE test: 62.113
# R^2 test: 0.526

# %% [markdown]
# ### **Random Forest - Feature Importance**

# %%
rf_features = pd.DataFrame()

rf_features['features'] = X_train.columns
rf_features['importance'] = rf.feature_importances_
rf_features.sort_values('importance', ascending=False).head(5)
# Out:
#               features  importance
# 4          room_typeid    0.244955
# 0      neighbourhoodid    0.127749
# 7            bathrooms    0.122260
# 6      amenities_count    0.093178
# 3  host_listings_count    0.067671

# %%
## Filter for top 5 features
rf_features_plot=rf_features.sort_values('importance', ascending=False).head(5)
rf_features_plot
# Out:
#               features  importance
# 4          room_typeid    0.244955
# 0      neighbourhoodid    0.127749
# 7            bathrooms    0.122260
# 6      amenities_count    0.093178
# 3  host_listings_count    0.067671

# %%
# make barplot and sort bars 
fig = plt.gcf()
fig.set_size_inches(10, 6)
rf_bar = sns.barplot(x='importance', y="features", data=rf_features_plot,  color= '#F05654', orient='h',
            order=rf_features_plot.features)
plt.title('Random Forest Regressor - Feature Importance', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Random Forest Regressor - Feature Importance')

# %%
from pprint import pprint
# Look at parameters used by our current forest
print('Parameters currently used:\n')
pprint(rf.get_params())
# Out:
# Parameters currently used:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 500,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'max_depth': [10, 20 ,40],
              'n_jobs':[3,4,5],
              'max_features': ['auto', 'sqrt', 'log2'],
              'n_estimators':[1000, 1500, 2000]}

grid = GridSearchCV(rf, param_grid, verbose=3)

# %%
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=3 ....
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=3, score=0.512, total=  36.0s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=3 ....
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   36.0s remaining:    0.0s
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=3, score=0.530, total=  34.4s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=3 ....
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.2min remaining:    0.0s
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=3, score=0.523, total=  34.2s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=3, score=0.495, total=  34.1s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=3, score=0.518, total=  34.2s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=4, score=0.512, total=  34.7s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=4, score=0.530, total=  34.4s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=4, score=0.523, total=  34.6s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=4, score=0.495, total=  34.3s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=4, score=0.518, total=  34.1s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=5, score=0.512, total=  34.8s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=5, score=0.530, total=  34.2s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=5, score=0.523, total=  34.4s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=5, score=0.495, total=  34.3s
# [CV] max_depth=10, max_features=auto, n_estimators=1000, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1000, n_jobs=5, score=0.518, total=  34.5s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=3, score=0.512, total=  51.3s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=3, score=0.529, total=  51.1s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=3, score=0.523, total=  51.0s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=3, score=0.495, total=  51.2s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=3, score=0.518, total=  51.3s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=4, score=0.512, total=  51.9s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=4, score=0.529, total=  51.3s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=4, score=0.523, total=  51.3s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=4, score=0.495, total=  51.3s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=4, score=0.518, total=  51.3s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=5, score=0.512, total=  51.9s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=5, score=0.529, total=  51.5s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=5, score=0.523, total=  51.4s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=5, score=0.495, total=  51.4s
# [CV] max_depth=10, max_features=auto, n_estimators=1500, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=1500, n_jobs=5, score=0.518, total=  51.7s
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=3, score=0.512, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=3, score=0.529, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=3, score=0.523, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=3, score=0.495, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=3, score=0.518, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=4, score=0.512, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=4, score=0.529, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=4, score=0.523, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=4, score=0.495, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=4, score=0.518, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=5, score=0.512, total= 1.2min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=5, score=0.529, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=5, score=0.523, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=5, score=0.495, total= 1.1min
# [CV] max_depth=10, max_features=auto, n_estimators=2000, n_jobs=5 ....
# [CV]  max_depth=10, max_features=auto, n_estimators=2000, n_jobs=5, score=0.518, total= 1.1min
# [CV] max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=3, score=0.496, total=   9.8s
# [CV] max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=3, score=0.498, total=   9.6s
# [CV] max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=3, score=0.507, total=   9.6s
# [CV] max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=3, score=0.484, total=   9.7s
# [CV] max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=3 ....
# [CV]  max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=3, score=0.494, total=   9.6s
# [CV] max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=4, score=0.496, total=  10.2s
# [CV] max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=4 ....
# [CV]  max_depth=10, max_features=sqrt, n_estimators=1000, n_jobs=4, score=0

# [CV] max_depth=40, max_features=log2, n_estimators=2000, n_jobs=4 ....
# [CV]  max_depth=40, max_features=log2, n_estimators=2000, n_jobs=4, score=0.546, total=  50.4s
# [CV] max_depth=40, max_features=log2, n_estimators=2000, n_jobs=4 ....
# [CV]  max_depth=40, max_features=log2, n_estimators=2000, n_jobs=4, score=0.522, total=  50.7s
# [CV] max_depth=40, max_features=log2, n_estimators=2000, n_jobs=4 ....
# [CV]  max_depth=40, max_features=log2, n_estimators=2000, n_jobs=4, score=0.537, total=  50.6s
# [CV] max_depth=40, max_features=log2, n_estimators=2000, n_jobs=5 ....
# [CV]  max_depth=40, max_features=log2, n_estimators=2000, n_jobs=5, score=0.533, total=  51.8s
# [CV] max_depth=40, max_features=log2, n_estimators=2000, n_jobs=5 ....
# [CV]  max_depth=40, max_features=log2, n_estimators=2000, n_jobs=5, score=0.541, total=  51.0s
# [CV] max_depth=40, max_features=log2, n_estimators=2000, n_jobs=5 ....
# [CV]  max_depth=40, max_features=log2, n_estimators=2000, n_jobs=5, score=0.546, total=  51.3s
# [CV] max_depth=40, max_features=log2, n_estimators=2000, n_jobs=5 ....
# [CV]  max_depth=40, max_features=log2, n_estimators=2000, n_jobs=5, score=0.522, total=  51.0s
# [CV] max_depth=40, max_features=log2, n_estimators=2000, n_jobs=5 ....
# [CV]  max_depth=40, max_features=log2, n_estimators=2000, n_jobs=5, score=0.537, total=  51.0s
# [Parallel(n_jobs=1)]: Done 405 out of 405 | elapsed: 321.7min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='sqrt',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=1000, n_jobs=3,
#                                              oob_score=False, random_state=42,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [10, 20, 40],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [1000, 1500, 2000],
#                          'n_jobs': [3, 4, 5]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-3d7817c5d645> in <module>()
# ----> 1 print(grid.best_params_)
#       2 print(grid.best_score_)
#
# NameError: name 'grid' is not defined

# %% [markdown]
# ### **LGBM Reggressor**

# %%
# Feature Selection
from lightgbm import LGBMRegressor

y = listings_cleaned['price']
x = listings_cleaned.drop('price', axis =1)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.35, random_state=1)

# %%
# Scale Data
from sklearn.preprocessing import LabelEncoder, MinMaxScaler,StandardScaler
from tensorflow.keras.utils import to_categorical

# Scale your data
from sklearn.preprocessing import StandardScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Run model with test data
fit_params={
    "early_stopping_rounds":20, 
            "eval_metric" : 'rmse', 
            "eval_set" : [(X_test,y_test)],
            'eval_names': ['valid'],
            'verbose': 100,
            'feature_name': 'auto', 
            'categorical_feature': 'auto'
           }

# %%
# Define class for rounds
class LGBMRegressor_GainFE(LGBMRegressor):
    @property
    def feature_importances_(self):
        if self._n_features is None:
            raise LGBMNotFittedError('No feature_importances found. Need to call fit beforehand.')
        return self.booster_.feature_importance(importance_type='gain')

# %%
# Run model
clf = LGBMRegressor_GainFE(num_leaves= 25, max_depth=20, 
                         random_state=0, 
                         silent=True, 
                         metric='rmse', 
                         n_jobs=4, 
                         n_estimators=1000,
                         colsample_bytree=0.9,
                         subsample=0.9,
                         learning_rate=0.01)
clf.fit(X_train.values, y_train.values, **fit_params)
# Out:
# Training until validation scores don't improve for 20 rounds.
# [100]	valid's rmse: 70.7165
# [200]	valid's rmse: 65.8181
# [300]	valid's rmse: 63.7949
# [400]	valid's rmse: 62.5476
# [500]	valid's rmse: 61.7359
# [600]	valid's rmse: 61.2611
# [700]	valid's rmse: 60.9495
# [800]	valid's rmse: 60.685
# [900]	valid's rmse: 60.4519
# [1000]	valid's rmse: 60.2874
# Did not meet early stopping. Best iteration is:
# [1000]	valid's rmse: 60.2874
# LGBMRegressor_GainFE(boosting_type='gbdt', class_weight=None,
#                      colsample_bytree=0.9, importance_type='split',
#                      learning_rate=0.01, max_depth=20, metric='rmse',
#                      min_child_samples=20, min_child_weight=0.001,
#                      min_split_gain=0.0, n_estimators=1000, n_jobs=4,
#                      num_leaves=25, objective=None, random_state=0,
#                      reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.9,
#                      subsample_for_bin=200000, subsample_freq=0)

# %%
# Print r2 & mean squared error results
y_train_pred = clf.predict(X_train.values)
y_test_pred = clf.predict(X_test.values)
rmse_rf= (mean_squared_error(y_test,y_test_pred))**(1/2)
print('RMSE test: %.5f' % rmse_rf)
print('R^2 test: %.5f' % (r2_score(y_test, y_test_pred)))
# Out:
# RMSE test: 60.28743
# R^2 test: 0.56138

# %% [markdown]
# ### **LGBM Features Importance**

# %%
lgbm_features = pd.DataFrame()

lgbm_features['features'] = X_train.columns
lgbm_features['importance'] = clf.feature_importances_
lgbm_features.sort_values('importance', ascending=False).head(20)
# Out:
#                   features    importance
# 4              room_typeid  1.902426e+09
# 7                bathrooms  8.745594e+08
# 0          neighbourhoodid  7.705048e+08
# 5             accommodates  5.561597e+08
# 8                 bedrooms  3.188058e+08
# 3      host_listings_count  2.913291e+08
# 6          amenities_count  1.192710e+08
# 14                  Washer  9.680086e+07
# 18       number_of_reviews  8.787109e+07
# 17          minimum_nights  8.652413e+07
# 12                 Kitchen  6.446914e+07
# 19    review_scores_rating  5.785544e+07
# 16                 Parking  3.582215e+07
# 9                     beds  3.293667e+07
# 1                superhost  2.145501e+07
# 2   host_identity_verified  1.887938e+07
# 13        Air Conditioning  1.461603e+07
# 11              Essentials  1.358443e+07
# 15                   Dryer  6.485084e+06
# 10                 Heating  3.684426e+06

# %%
lgbm_features=lgbm_features.sort_values('importance', ascending=False).head(5)
lgbm_features
# Out:
#           features    importance
# 4      room_typeid  1.902426e+09
# 7        bathrooms  8.745594e+08
# 0  neighbourhoodid  7.705048e+08
# 5     accommodates  5.561597e+08
# 8         bedrooms  3.188058e+08

# %%
# make barplot and sort bars 
fig = plt.gcf()
fig.set_size_inches(10, 6)
sns.barplot(x='importance', 
            y="features", data=lgbm_features,  color= '#F05654', orient='h',
            order=lgbm_features.features)
plt.title('LGBM Regressor - Feature Importance', fontsize=16)
# Out:
# Text(0.5, 1.0, 'LGBM Regressor - Feature Importance')

# %% [markdown]
# ### **KNN Regressor**

# %%
# Import dependencies
from sklearn.neighbors import KNeighborsRegressor

# Create empty lists to store score values of training & test data
train_scores = []
test_scores = []

# Create for loop to run the scores of the different data
for k in range(1, 31, 2):
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
# Plot results in line graph
plt.plot(range(1, 31, 2), train_scores, marker='o')
plt.plot(range(1, 31, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 0.995/0.051
# k: 3, Train/Test Score: 0.686/0.338
# k: 5, Train/Test Score: 0.605/0.383
# k: 7, Train/Test Score: 0.564/0.401
# k: 9, Train/Test Score: 0.537/0.406
# k: 11, Train/Test Score: 0.521/0.413
# k: 13, Train/Test Score: 0.507/0.412
# k: 15, Train/Test Score: 0.496/0.412
# k: 17, Train/Test Score: 0.487/0.412
# k: 19, Train/Test Score: 0.480/0.413
# k: 21, Train/Test Score: 0.475/0.414
# k: 23, Train/Test Score: 0.470/0.414
# k: 25, Train/Test Score: 0.465/0.412
# k: 27, Train/Test Score: 0.461/0.411
# k: 29, Train/Test Score: 0.456/0.410

# %%
# Run model for k value with the lowest difference between train & test scores
knn = KNeighborsRegressor(n_neighbors=29)
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=29, p=2,
#                     weights='uniform')

# %%
# Calculate r2 & mean squared error score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

y_train_pred = knn.predict(X_train_scaled)
y_test_pred = knn.predict(X_test_scaled)
rmse_rf= (mean_squared_error(y_test,y_test_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_test_pred)))
# Out:
# RMSE test: 69.924
# R^2 test: 0.410
