# %%
import pandas as pd
from fbprophet import Prophet

# %%
calendar_final = pd.read_csv('calendar_final.csv')
calendar_final
# Out:
#       Unnamed: 0          ds           y
# 0              0  2017-01-01  201.552956
# 1              1  2017-01-02  164.727980
# 2              2  2017-01-03  151.504622
# 3              3  2017-01-04  145.545741
# 4              4  2017-01-05  142.318020
# ...          ...         ...         ...
# 1821        1821  2021-12-27  181.956220
# 1822        1822  2021-12-28  183.071290
# 1823        1823  2021-12-29  183.354279
# 1824        1824  2021-12-30  185.625613
# 1825        1825  2021-12-31  188.902854
#
# [1826 rows x 3 columns]

# %%
model = Prophet()
model.fit(calendar_final)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
calendar_final.tail()
# Out:
#       Unnamed: 0          ds           y
# 1821        1821  2021-12-27  181.956220
# 1822        1822  2021-12-28  183.071290
# 1823        1823  2021-12-29  183.354279
# 1824        1824  2021-12-30  185.625613
# 1825        1825  2021-12-31  188.902854

# %%
future_df = model.make_future_dataframe(periods=365)
future_df
# Out:
#              ds
# 0    2017-01-01
# 1    2017-01-02
# 2    2017-01-03
# 3    2017-01-04
# 4    2017-01-05
# ...         ...
# 2186 2022-12-27
# 2187 2022-12-28
# 2188 2022-12-29
# 2189 2022-12-30
# 2190 2022-12-31
#
# [2191 rows x 1 columns]

# %%
predictions = model.predict(future_df)
predictions
# Out:
#              ds       trend  ...  multiplicative_terms_upper        yhat
# 0    2017-01-01  154.632392  ...                         0.0  157.123542
# 1    2017-01-02  154.648089  ...                         0.0  155.542388
# 2    2017-01-03  154.663786  ...                         0.0  153.842375
# 3    2017-01-04  154.679483  ...                         0.0  152.565278
# 4    2017-01-05  154.695180  ...                         0.0  151.058623
# ...         ...         ...  ...                         ...         ...
# 2186 2022-12-27  180.185955  ...                         0.0  185.982993
# 2187 2022-12-28  180.194377  ...                         0.0  185.708726
# 2188 2022-12-29  180.202800  ...                         0.0  185.111208
# 2189 2022-12-30  180.211222  ...                         0.0  189.875096
# 2190 2022-12-31  180.219644  ...                         0.0  189.484902
#
# [2191 rows x 19 columns]

# %%
model.plot(predictions)

# %%
model.plot_components(predictions)
