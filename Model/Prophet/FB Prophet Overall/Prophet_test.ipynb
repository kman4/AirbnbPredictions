# %%
import pandas as pd
from fbprophet import Prophet

# %%
df = pd.read_csv('calendar.csv')
df.head()
# Out:
#    listing_id        date  ... minimum_nights maximum_nights
# 0       42729  2021-01-11  ...           30.0           90.0
# 1        2595  2021-01-09  ...           30.0         1125.0
# 2        2595  2021-01-10  ...           30.0         1125.0
# 3        2595  2021-01-11  ...           30.0         1125.0
# 4        2595  2021-01-12  ...           30.0         1125.0
#
# [5 rows x 7 columns]

# %%
df.dtypes
# Out:
# listing_id                 int64
# date              datetime64[ns]
# available                 object
# price                     object
# adjusted_price            object
# minimum_nights           float64
# maximum_nights           float64
# dtype: object

# %%
df['date']= pd.to_datetime(df['date'])

# %%
calendar_2021 = df.loc[df['date'] < "2022-1-1"]
calendar_2021
# Out:
#           listing_id       date  ... minimum_nights maximum_nights
# 0              42729 2021-01-11  ...           30.0           90.0
# 1               2595 2021-01-09  ...           30.0         1125.0
# 2               2595 2021-01-10  ...           30.0         1125.0
# 3               2595 2021-01-11  ...           30.0         1125.0
# 4               2595 2021-01-12  ...           30.0         1125.0
# ...              ...        ...  ...            ...            ...
# 13554635    46867150 2021-12-27  ...            3.0         1125.0
# 13554636    46867150 2021-12-28  ...            3.0         1125.0
# 13554637    46867150 2021-12-29  ...            3.0         1125.0
# 13554638    46867150 2021-12-30  ...            3.0         1125.0
# 13554639    46867150 2021-12-31  ...            3.0         1125.0
#
# [13212632 rows x 7 columns]

# %%
calendar_2021 = calendar_2021.loc[calendar_2021['available'] == "t"]
calendar_2021
# Out:
#           listing_id       date  ... minimum_nights maximum_nights
# 0              42729 2021-01-11  ...           30.0           90.0
# 1               2595 2021-01-09  ...           30.0         1125.0
# 2               2595 2021-01-10  ...           30.0         1125.0
# 3               2595 2021-01-11  ...           30.0         1125.0
# 4               2595 2021-01-12  ...           30.0         1125.0
# ...              ...        ...  ...            ...            ...
# 13554460    46867150 2021-07-05  ...            3.0         1125.0
# 13554461    46867150 2021-07-06  ...            3.0         1125.0
# 13554462    46867150 2021-07-07  ...            3.0         1125.0
# 13554463    46867150 2021-07-08  ...            3.0         1125.0
# 13554464    46867150 2021-07-09  ...            3.0         1125.0
#
# [5069634 rows x 7 columns]

# %%
calendar_2021['price'] = calendar_2021['price'].str.replace('$', '')
calendar_2021['price'] = calendar_2021['price'].str.replace(',', '')
calendar_2021
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           listing_id       date  ... minimum_nights maximum_nights
# 0              42729 2021-01-11  ...           30.0           90.0
# 1               2595 2021-01-09  ...           30.0         1125.0
# 2               2595 2021-01-10  ...           30.0         1125.0
# 3               2595 2021-01-11  ...           30.0         1125.0
# 4               2595 2021-01-12  ...           30.0         1125.0
# ...              ...        ...  ...            ...            ...
# 13554460    46867150 2021-07-05  ...            3.0         1125.0
# 13554461    46867150 2021-07-06  ...            3.0         1125.0
# 13554462    46867150 2021-07-07  ...            3.0         1125.0
# 13554463    46867150 2021-07-08  ...            3.0         1125.0
# 13554464    46867150 2021-07-09  ...            3.0         1125.0
#
# [5069634 rows x 7 columns]

# %%
calendar_2021['price'] = calendar_2021['price'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
calendar_model = calendar_2021.groupby(['date']).mean().reset_index()
calendar_model
# Out:
#           date    listing_id       price  minimum_nights  maximum_nights
# 0   2021-01-08  3.877157e+07  270.846154       41.307692    2.202556e+08
# 1   2021-01-09  2.763448e+07  194.466555       27.527592    1.975196e+07
# 2   2021-01-10  2.817463e+07  164.166401       23.124801    1.368633e+07
# 3   2021-01-11  2.842510e+07  159.294189       22.271414    1.017964e+07
# 4   2021-01-12  2.806715e+07  157.803842       21.962349    7.485672e+06
# ..         ...           ...         ...             ...             ...
# 353 2021-12-27  2.668430e+07  181.956220       37.331051    4.902963e+06
# 354 2021-12-28  2.667962e+07  183.071290       37.308472    4.900064e+06
# 355 2021-12-29  2.667055e+07  183.354279       37.358001    4.906280e+06
# 356 2021-12-30  2.667112e+07  185.625613       37.345224    4.903792e+06
# 357 2021-12-31  2.662976e+07  188.902854       37.418226    4.913344e+06
#
# [358 rows x 5 columns]

# %%
calendar_model=calendar_model[['date', 'price']]
calendar_model
# Out:
#           date       price
# 0   2021-01-08  270.846154
# 1   2021-01-09  194.466555
# 2   2021-01-10  164.166401
# 3   2021-01-11  159.294189
# 4   2021-01-12  157.803842
# ..         ...         ...
# 353 2021-12-27  181.956220
# 354 2021-12-28  183.071290
# 355 2021-12-29  183.354279
# 356 2021-12-30  185.625613
# 357 2021-12-31  188.902854
#
# [358 rows x 2 columns]

# %%
calendar_model = calendar_model.rename(columns={"date": "ds", "price": "y"})

# %%
model = Prophet()
model.fit(calendar_model)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
calendar_model.tail()
# Out:
#             ds           y
# 353 2021-12-27  181.956220
# 354 2021-12-28  183.071290
# 355 2021-12-29  183.354279
# 356 2021-12-30  185.625613
# 357 2021-12-31  188.902854

# %%
future_df = model.make_future_dataframe(periods=365)
future_df
# Out:
#             ds
# 0   2021-01-08
# 1   2021-01-09
# 2   2021-01-10
# 3   2021-01-11
# 4   2021-01-12
# ..         ...
# 718 2022-12-27
# 719 2022-12-28
# 720 2022-12-29
# 721 2022-12-30
# 722 2022-12-31
#
# [723 rows x 1 columns]

# %%
predictions = model.predict(future_df)
predictions
# Out:
#             ds       trend  ...  multiplicative_terms_upper        yhat
# 0   2021-01-08  171.787586  ...                         0.0  175.747325
# 1   2021-01-09  171.181040  ...                         0.0  173.930807
# 2   2021-01-10  170.574493  ...                         0.0  168.954958
# 3   2021-01-11  169.967946  ...                         0.0  168.398706
# 4   2021-01-12  169.361400  ...                         0.0  168.108474
# ..         ...         ...  ...                         ...         ...
# 718 2022-12-27  218.764104  ...                         0.0  217.511178
# 719 2022-12-28  218.864714  ...                         0.0  217.718173
# 720 2022-12-29  218.965324  ...                         0.0  217.844059
# 721 2022-12-30  219.065934  ...                         0.0  223.025673
# 722 2022-12-31  219.166543  ...                         0.0  221.916311
#
# [723 rows x 16 columns]

# %%
model.plot(predictions)

# %%
calendar_model.describe
# Out:
# <bound method NDFrame.describe of             ds           y
# 0   2021-01-08  270.846154
# 1   2021-01-09  194.466555
# 2   2021-01-10  164.166401
# 3   2021-01-11  159.294189
# 4   2021-01-12  157.803842
# ..         ...         ...
# 353 2021-12-27  181.956220
# 354 2021-12-28  183.071290
# 355 2021-12-29  183.354279
# 356 2021-12-30  185.625613
# 357 2021-12-31  188.902854
#
# [358 rows x 2 columns]>

# %%
model.plot_components(predictions)
